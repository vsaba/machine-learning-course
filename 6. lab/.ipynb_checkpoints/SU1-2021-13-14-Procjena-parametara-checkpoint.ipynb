# %% [markdown]
# Sveučilište u Zagrebu
# Fakultet elektrotehnike i računarstva
#
# ## Strojno učenje 1 2021/2022
# http://www.fer.unizg.hr/predmet/struce1

# %% [markdown]
# ------------------------------
#
# ### Procjena parametara
#
# *Verzija: 1.0
# Zadnji put ažurirano: 1. listopada 2021.*
#
# (c) 2015-2021 Jan Šnajder, Domagoj Alagić
#
# Rok za predaju: **19. prosinca 2021. u 23:59h**
#
# ------------------------------

# %% [markdown]
# ### Upute
#
# Ova laboratorijska vježba sastoji se od tri zadatka. U nastavku slijedite upute navedene u ćelijama s tekstom. Rješavanje vježbe svodi se na **dopunjavanje ove bilježnice**: umetanja ćelije ili više njih **ispod** teksta zadatka, pisanja odgovarajućeg kôda te evaluiranja ćelija.
#
# Osigurajte da u potpunosti **razumijete** kôd koji ste napisali. Kod predaje vježbe, morate biti u stanju na zahtjev asistenta (ili demonstratora) preinačiti i ponovno evaluirati Vaš kôd. Nadalje, morate razumjeti teorijske osnove onoga što radite, u okvirima onoga što smo obradili na predavanju. Ispod nekih zadataka možete naći i pitanja koja služe kao smjernice za bolje razumijevanje gradiva (**nemojte pisati** odgovore na pitanja u bilježnicu). Stoga se nemojte ograničiti samo na to da riješite zadatak, nego slobodno eksperimentirajte. To upravo i jest svrha ovih vježbi.
#
# Vježbe trebate raditi **samostalno**. Možete se konzultirati s drugima o načelnom načinu rješavanja, ali u konačnici morate sami odraditi vježbu. U protivnome vježba nema smisla.

# %%
# Učitaj osnovne biblioteke...
import sklearn
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np
import matplotlib.pyplot as plt
#import pgmpy as pgm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 1. Procjena maksimalne izglednosti

# %% [markdown]
# #### (a)
#
# Definirajte funkciju izglednosti $\mathcal{L}(\mu|\mathcal{D})$ za skup $\mathcal{D}=\{x^{(i)}\}_{i=1}^N$ Bernoullijevih varijabli. Neka od $N$ varijabli njih $m$ ima vrijednost 1 (npr. od $N$ bacanja novčića, $m$ puta smo dobili glavu). Definirajte funkciju izglednosti tako da je parametrizirana s $N$ i $m$, dakle definirajte funkciju $\mathcal{L}(\mu|N,m)$.

# %%
def L(mu, N, m):
    return pow(mu, m) * pow(1 - mu, N - m)

# %%
mu = np.linspace(0, 1, 100)

# %%
plt.plot(mu, [L(x, 10, 8) for x in mu])
plt.show()

# %% [markdown]
# #### (b)

# %% [markdown]
# Prikažite funkciju $\mathcal{L}(\mu|N,m)$ za (1) $N=10$ i $m=1,2,5,9$ te za (2) $N=100$ i $m=1,10,50,90$ (dva zasebna grafikona).

# %%
for m in [1, 2, 5, 9]:
    plt.plot(mu, [L(x, 10, m) for x in mu], label="m={0}".format(m))

plt.legend(loc="upper center")
plt.show()

# %%
for m in [1, 10, 50, 90]:
    plt.plot(mu, [L(x, 100, m) for x in mu], label="m={0}".format(m))

plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Q:** Koja vrijednost odgovara ML-procjenama i zašto?

# %% [markdown]
# #### (c)
#
# Prikažite funkciju $\mathcal{L}(\mu|N,m)$ za $N=10$ i $m=\{0,9\}$.

# %%
plt.plot(mu, [L(x, 10, 0) for x in mu], label="m={0}".format(m))
plt.legend(loc="upper center")
plt.show()

# %%
plt.plot(mu, [L(x, 10, 9) for x in mu], label="m={0}".format(m))
plt.legend(loc="upper center")
plt.show()

# %% [markdown]
# **Q:** Koja je ML-procjena za $\mu$ i što je problem s takvom procjenom u ovome slučaju?

# %% [markdown]
# ### 2. Procjena maksimalne aposteriorne vjerojatnosti

# %% [markdown]
# #### (a)
#
# Prikažite beta-distribuciju $B(\mu|\alpha,\beta)$ za različite kombinacije parametara $\alpha$ i $\beta$, uključivo $\alpha=\beta=1$ te $\alpha=\beta=2$.

# %%
from scipy.stats import beta

plt.plot(mu, beta.pdf(mu, 1, 1), label="a=b=1")
plt.plot(mu, beta.pdf(mu, 2, 2), label="a=b=2")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Q:** Koje parametere biste odabrali za modeliranje apriornog znanja o parametru $\mu$ za novčić za koji mislite da je "donekle pravedan, ali malo češće pada na glavu"? Koje biste parametre odabrali za novčić za koji držite da je posve pravedan? Zašto uopće koristimo beta-distribuciju, a ne neku drugu?

# %% [markdown]
# #### (b)
#
# Definirajte funkciju za izračun zajedničke vjerojatnosti $P(\mu,\mathcal{D}) = P(\mathcal{D}|\mu) \cdot P(\mu|\alpha,\beta)$ te prikažite tu funkciju za $N=10$ i $m=9$ i nekolicinu kombinacija parametara $\alpha$ i $\beta$.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def P_mi_D(mu, N, m, a, b):
    return L(mu, N, m) * P_mi_a_b(mu, a, b)

def P_mi_a_b(mu, a, b):
    return (1 / beta.pdf(mu, a, b)) * (pow(mu, a - 1)) * (pow(1 - mu, b - 1))

# %%
plt.plot(mu, [P_mi_D(x, 10, 9, 1, 1) for x in mu], label="a = 1, b = 1")
plt.plot(mu, [P_mi_D(x, 10, 9, 1, 2) for x in mu], label="a = 1, b = 2")
plt.plot(mu, [P_mi_D(x, 10, 9, 1, 3) for x in mu], label="a = 1, b = 3")
plt.plot(mu, [P_mi_D(x, 10, 9, 2, 1) for x in mu], label="a = 2, b = 1")
plt.plot(mu, [P_mi_D(x, 10, 9, 2, 2) for x in mu], label="a = 2, b = 2")
plt.plot(mu, [P_mi_D(x, 10, 9, 2, 3) for x in mu], label="a = 2, b = 3")
plt.plot(mu, [P_mi_D(x, 10, 9, 3, 1) for x in mu], label="a = 3, b = 1")
plt.plot(mu, [P_mi_D(x, 10, 9, 3, 2) for x in mu], label="a = 3, b = 2")
plt.plot(mu, [P_mi_D(x, 10, 9, 3, 3) for x in mu], label="a = 3, b = 3")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# **Q**: Koje vrijednosti odgovaraju MAP-procjeni za $\mu$? Usporedite ih sa ML-procjenama.

# %% [markdown]
# #### (c)
#
# Za $N=10$ i $m=1$, na jednome grafikonu prikažite sve tri distribucije: $P(\mu,\mathcal{D})$, $P(\mu|\alpha,\beta)$ i $\mathcal{L}(\mu|\mathcal{D})$.

# %%
plt.plot(mu, [P_mi_D(x, 10, 1, 2, 2) for x in mu], label="P(mi, D)")
plt.plot(mu, [P_mi_a_b(x, 2, 2) for x in mu], label="P(mi|a, b)")
plt.plot(mu, [L(x, 10, 1) for x in mu], label="L(mi|D)")

plt.legend(loc="center right")
plt.show()

# %% [markdown]
# ### 3. Analiza skupa podataka *Iris*

# %% [markdown]
# #### (a)
#
# Učitajte skup podataka *Iris* korištenjem funkcije [`load_iris`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html). Taj skup sadrži $n=4$ značajke i $K=3$ klase. Odaberite jednu klasu i odaberite sve primjere iz te klase, dok ostale primjere zanemarite (**u nastavku radite isključivo s primjerima iz te jedne klase**). Vizualizirajte podatke tako da načinite 2D-prikaze za svaki par značajki (šest grafikona; za prikaz je najjednostavnije koristiti funkciju [`scatter`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)).
#
# **NB:** Mogla bi Vam dobro dući funkcija [`itertools.combinations`](https://docs.python.org/2/library/itertools.html#itertools.combinations).

# %%
from sklearn.datasets import load_iris
import itertools as it

iris, iris_target = load_iris(return_X_y=True)
iris = iris[np.where(iris_target == 2), :]
iris = np.squeeze(iris)

# %%
plt.scatter(iris[:, 0], iris[:, 1])
plt.title("1. i 2. značajka")
plt.show()

plt.scatter(iris[:, 0], iris[:, 2])
plt.title("1. i 3. značajka")
plt.show()

plt.scatter(iris[:, 0], iris[:, 3])
plt.title("1. i 4. značajka")
plt.show()

plt.scatter(iris[:, 1], iris[:, 2])
plt.title("2. i 3. značajka")
plt.show()

plt.scatter(iris[:, 1], iris[:, 3])
plt.title("2. i 4. značajka")
plt.show()

plt.scatter(iris[:, 2], iris[:, 3])
plt.title("3. i 4. značajka")
plt.show()

# %% [markdown]
# #### (b)
#
# Pogledajte opis modula [`stats`](http://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html) te proučite funkciju [`norm`](http://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.norm.html#scipy.stats.norm). Implementirajte funkciju log-izglednosti za parametre $\mu$ i $\sigma^2$ normalne distribucije.

# %%
from scipy.stats import norm

def L_gauss(x, mi=0, sigma=1):
    rv = norm(loc=mi, scale=sigma)
    mul = 1
    for i in x:
        mul *= rv.pdf(i)
    
    return log(mul)

# %% [markdown]
# #### (c)
# Izračunajte ML-procjene za $(\mu, \sigma^2)$ za svaku od $n=4$ značajki iz skupa *Iris*. Ispišite log-izglednosti tih ML-procjena.

# %%
np.mean(iris[:, 0])
rv = norm(loc=1, scale=sqrt(25))
rv.mean(), rv.var()
# Out:
# (1.0, 25.0)

# %%
def MLE(x):
    mean = np.mean(x)
    var = 0
    for i in x:
        var += math.pow((i - mean), 2)
    
    var /= np.size(x)
    return mean, var

# %%
for n in range(0, 4):
    x = iris[:, n]
    mean, var = MLE(x)
    print("log-izglednost {0}. značajke: {1}, mi = {2}, sigma = {3}".format(n + 1, L_gauss(x, mean , var), mean, var))
# Out:
# log-izglednost 1. značajke: -62.75271339862489, mi = 6.587999999999998, sigma = 0.39625599999999994
# log-izglednost 2. značajke: -177.05133204413292, mi = 2.974, sigma = 0.10192399999999999
# log-izglednost 3. značajke: -69.25020545501907, mi = 5.5520000000000005, sigma = 0.29849600000000004
# log-izglednost 4. značajke: -253.8962027728251, mi = 2.0260000000000002, sigma = 0.07392399999999998

# %% [markdown]
# #### (d)
#
# Proučite funkciju [`pearsonr`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html) za izračun Pearsonovog koeficijenta korelacije. Izračunajte koeficijente korelacije između svih četiri značajki u skupu *Iris*.

# %%
from scipy.stats import pearsonr

print("Korelacija 1. i 2. značajke: {0}".format(pearsonr(iris[:, 0], iris[:, 1])[0]))
print("Korelacija 1. i 3. značajke: {0}".format(pearsonr(iris[:, 0], iris[:, 2])[0]))
print("Korelacija 1. i 4. značajke: {0}".format(pearsonr(iris[:, 0], iris[:, 3])[0]))
print("Korelacija 2. i 3. značajke: {0}".format(pearsonr(iris[:, 1], iris[:, 2])[0]))
print("Korelacija 2. i 4. značajke: {0}".format(pearsonr(iris[:, 1], iris[:, 3])[0]))
print("Korelacija 3. i 4. značajke: {0}".format(pearsonr(iris[:, 2], iris[:, 3])[0]))
# Out:
# Korelacija 1. i 2. značajke: 0.45722781639411314
# Korelacija 1. i 3. značajke: 0.8642247329355762
# Korelacija 1. i 4. značajke: 0.2811077091573194
# Korelacija 2. i 3. značajke: 0.40104457734278554
# Korelacija 2. i 4. značajke: 0.5377280262661888
# Korelacija 3. i 4. značajke: 0.32210821590031835

# %% [markdown]
# #### (e)
#
# Proučite funkciju [`cov`](http://docs.scipy.org/doc/numpy/reference/generated/numpy.cov.html) te izračunajte ML-procjenu za kovarijacijsku matricu za skup *Iris*. Usporedite pristranu i nepristranu procjenu. Pokažite da se razlika (srednja apsolutna i kvadratna) smanjuje s brojem primjera (npr. isprobajte za $N/4$ i $N/2$ i $N$ primjera).

# %%
pristrana = np.cov(iris[: int(floor(len(iris) / 4))], rowvar=False, bias=True)
nepristrana = np.cov(iris, rowvar=False, bias=False)
print("Razlika pristrane i nepristrane za N = {0}: {1}".format(int(floor(len(iris) / 4)), np.mean(pristrana - nepristrana)))
# Out:
# Razlika pristrane i nepristrane za N = 12: 0.021423168225623554

# %%
pristrana = np.cov(iris[: int(floor(len(iris) / 2))], rowvar=False, bias=True)
nepristrana = np.cov(iris, rowvar=False, bias=False)
print("Razlika pristrane i nepristrane za N = {0}: {1}".format(int(floor(len(iris) / 2)), np.mean(pristrana - nepristrana)))
# Out:
# Razlika pristrane i nepristrane za N = 25: 0.03704559183673471

# %%
pristrana = np.cov(iris, rowvar=False, bias=True)
nepristrana = np.cov(iris, rowvar=False, bias=False)
print("Razlika pristrane i nepristrane za N = {0}: {1}".format(len(iris), np.mean(pristrana - nepristrana)))
# Out:
# Razlika pristrane i nepristrane za N = 50: -0.002645408163265291
